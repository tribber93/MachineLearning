# %% [markdown]
# <a href="https://colab.research.google.com/github/tribber93/MachineLearning/blob/main/Praktikum_04(ambil_data).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2f4c7c17-6523-4175-baa0-ff84c43b70ce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f4c7c17-6523-4175-baa0-ff84c43b70ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# ref                                                             title                                            size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  ----------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# akshaydattatraykhare/diabetes-dataset                           Diabetes Dataset                                  9KB  2022-10-06 08:55:25           9728        311  1.0
# whenamancodes/covid-19-coronavirus-pandemic-dataset             COVID -19 Coronavirus Pandemic Dataset           11KB  2022-09-30 04:05:11           7804        248  1.0
# stetsondone/video-game-sales-by-genre                           Video Game Sales by Genre                        12KB  2022-10-31 17:56:01            414         23  1.0
# ...

# %%
# !kaggle datasets list -s "Reddit Vaccine Myths"
# Out:
# ref                              title                  size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------  --------------------  -----  -------------------  -------------  ---------  ---------------
# gpreda/reddit-vaccine-myths      Reddit Vaccine Myths  237KB  2022-02-10 18:16:00          19616       1490  1.0
# zhonghaohe/reddit-vaccine-myths  Reddit Vaccine Myths   24KB  2021-08-21 08:01:44              5          1  0.125
# bhargavramdr/vaccine-myth        Vaccine_myth          235KB  2021-09-14 13:26:00              4          2  0.1764706

# %%
# !kaggle datasets download -d gpreda/reddit-vaccine-myths
# Out:
# ...
#   0% 0.00/237k [00:00<?, ?B/s]
# 100% 237k/237k [00:00<00:00, 62.0MB/s]

# %%
# !unzip "reddit-vaccine-myths/reddit-vaccine-myths.zip" -d "check/"
# Out:
# Archive:  reddit-vaccine-myths/reddit-vaccine-myths.zip
#   inflating: check/reddit_vm.csv

# %%
import pandas as pd
import numpy as np

# %%
path = "/content/reddit-vaccine-myths/reddit_vm.csv"
df = pd.read_csv(path)

# %%
df
# Out:
#                                                   title  score       id  \
# 0     Health Canada approves AstraZeneca COVID-19 va...      7   lt74vw
# 1     COVID-19 in Canada: 'Vaccination passports' a ...      2   lsh0ij
# 2     Coronavirus variants could fuel Canada's third...      6   lohlle
# 3     Canadian government to extend COVID-19 emergen...      1   lnptv8
# 4     Canada: Pfizer is 'extremely committed' to mee...      6   lkslm6
# ...                                                 ...    ...      ...
# 1597                                            Comment      2  elrv9ua
# 1598                                            Comment      1  elrud7d
# 1599                                            Comment      0  elrtjl5
# 1600                                            Comment      1  elrrt5l
# 1601                                            Comment      1  elrqfk3
#
#                                                     url  comms_num  \
# ...

# %%
df.head(20)
# Out:
#                                                 title  score       id  \
# 0   Health Canada approves AstraZeneca COVID-19 va...      7   lt74vw
# 1   COVID-19 in Canada: 'Vaccination passports' a ...      2   lsh0ij
# 2   Coronavirus variants could fuel Canada's third...      6   lohlle
# 3   Canadian government to extend COVID-19 emergen...      1   lnptv8
# 4   Canada: Pfizer is 'extremely committed' to mee...      6   lkslm6
# 5   Canada: Oxford-AstraZeneca vaccine approval ex...      5   lftbji
# 6                                             Comment      1  ej9x066
# 7                       Fuck you anti-vaxxing retards     10   g6jkhp
# 8                                             Comment      0  fofa0yy
# 9                                             Comment      0  ej9xuaf
# 10                                            Comment      1  ej9x2qr
# 11                                            Comment      2  ejacj98
# ...

# %%
print(df.dtypes) #tipe data setiap kolom
# Out:
# title         object
# score          int64
# id            object
# url           object
# comms_num      int64
# created      float64
# body          object
# timestamp     object
# dtype: object

# %%
df.describe()
# Out:
#              score    comms_num       created
# count  1602.000000  1602.000000  1.602000e+03
# mean      3.686642     1.838951  1.547197e+09
# std      29.915671    16.115147  7.099511e+07
# min     -12.000000     0.000000  1.389595e+09
# 25%       1.000000     0.000000  1.554367e+09
# 50%       1.000000     0.000000  1.569226e+09
# 75%       3.000000     1.000000  1.584901e+09
# max    1187.000000   595.000000  1.640822e+09
