# %% [markdown]
# <a href="https://colab.research.google.com/github/tribber93/MachineLearning/blob/main/UTS_Machine_Learning_no_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
path = '/content/drive/MyDrive/Machine Learning/dataset/dataset_uts-2021.csv'
df = pd.read_csv(path)
df
# Out:
#    No           Name                  Address  Mobile Phone   Project  \
# 0   1    Princy Odom        Street 1 New Lane   789456120.0    Client
# 1   2     Appy Alexa                Ac Street   568798821.0    Client
# 2   3      Luna Knox     PO.BOX 12-Loren Park           NaN       NaN
# 3   4  Clark Andrews   PO.BOX 156-Settle Road   123545342.0    Client
# 4   5     Riley Drew  PO.BOX 16-Thames Street   789821211.0   intenal
# 5   6    August Bork  PO.BOX 17-Thames Street   125921931.0  Internal
# 6   7     Riley Drew  PO.BOX 16-Thames Street   789821211.0  Internal
# 7   8            XYS        Street 12 New Way           0.0       NaN
# 8   9    Erica Flint   Street 7 New Lane Road   789456128.0  Internal
#
#              Email
# 0  princy@text.com
# 1    appy@text.com
# 2    luna@text.com
# 3   clark@text.com
# 4   riley@text.com
# 5     aug@text.com
# 6   riley@text.com
# 7              NaN
# 8   erica@text.com

# %%
df.dtypes
# Out:
# No                int64
# Name             object
# Address          object
# Mobile Phone    float64
# Project          object
# Email            object
# dtype: object

# %%
# a. Menghapus baris yang hilang
df.dropna(inplace = True)
# Menghapus data double "Riley Drew"
df = df.drop(6)
df
# Out:
#    No           Name                  Address  Mobile Phone   Project  \
# 0   1    Princy Odom        Street 1 New Lane   789456120.0    Client
# 1   2     Appy Alexa                Ac Street   568798821.0    Client
# 3   4  Clark Andrews   PO.BOX 156-Settle Road   123545342.0    Client
# 4   5     Riley Drew  PO.BOX 16-Thames Street   789821211.0   intenal
# 5   6    August Bork  PO.BOX 17-Thames Street   125921931.0  Internal
# 8   9    Erica Flint   Street 7 New Lane Road   789456128.0  Internal
#
#              Email
# 0  princy@text.com
# 1    appy@text.com
# 3   clark@text.com
# 4   riley@text.com
# 5     aug@text.com
# 8   erica@text.com

# %%
# b. Menghapus kolom yang berisi data yang tidak relevan (Hapus Kolom No)
df.drop(["No"],inplace=True,axis=1)
df
# Out:
#             Name                  Address  Mobile Phone   Project  \
# 0    Princy Odom        Street 1 New Lane   789456120.0    Client
# 1     Appy Alexa                Ac Street   568798821.0    Client
# 3  Clark Andrews   PO.BOX 156-Settle Road   123545342.0    Client
# 4     Riley Drew  PO.BOX 16-Thames Street   789821211.0   intenal
# 5    August Bork  PO.BOX 17-Thames Street   125921931.0  Internal
# 8    Erica Flint   Street 7 New Lane Road   789456128.0  Internal
#
#              Email
# 0  princy@text.com
# 1    appy@text.com
# 3   clark@text.com
# 4   riley@text.com
# 5     aug@text.com
# 8   erica@text.com

# %%
# c. Perbaiki kesalahan input (intenal harusnya Internal)
df.loc[4,'Project'] = "Internal"
df
# Out:
#             Name                  Address  Mobile Phone   Project  \
# 0    Princy Odom        Street 1 New Lane   789456120.0    Client
# 1     Appy Alexa                Ac Street   568798821.0    Client
# 3  Clark Andrews   PO.BOX 156-Settle Road   123545342.0    Client
# 4     Riley Drew  PO.BOX 16-Thames Street   789821211.0  Internal
# 5    August Bork  PO.BOX 17-Thames Street   125921931.0  Internal
# 8    Erica Flint   Street 7 New Lane Road   789456128.0  Internal
#
#              Email
# 0  princy@text.com
# 1    appy@text.com
# 3   clark@text.com
# 4   riley@text.com
# 5     aug@text.com
# 8   erica@text.com

# %%
# d. Ubah Tipe data float64 untuk Mobile Phone menjadi Teks atau Object

# convert ke int untuk menghapus .0 lalu baru ke string
df['Mobile Phone'] = df['Mobile Phone'].astype(int).astype(str) 
df
# Out:
#             Name                  Address Mobile Phone   Project  \
# 0    Princy Odom        Street 1 New Lane    789456120    Client
# 1     Appy Alexa                Ac Street    568798821    Client
# 3  Clark Andrews   PO.BOX 156-Settle Road    123545342    Client
# 4     Riley Drew  PO.BOX 16-Thames Street    789821211  Internal
# 5    August Bork  PO.BOX 17-Thames Street    125921931  Internal
# 8    Erica Flint   Street 7 New Lane Road    789456128  Internal
#
#              Email
# 0  princy@text.com
# 1    appy@text.com
# 3   clark@text.com
# 4   riley@text.com
# 5     aug@text.com
# 8   erica@text.com

# %%
df.dtypes
# Out:
# Name            object
# Address         object
# Mobile Phone    object
# Project         object
# Email           object
# dtype: object

# %%
# e. Ganti nama semua kolom dalam bahasa Indonesia
df = df.rename(columns={
    'Name': 'Nama', 
    'Address':'Alamat', 
    'Mobile Phone':'Nomor Handphone',
    'Project': 'Projek'
}) 
df
# Out:
#             Nama                   Alamat Nomor Handphone    Projek  \
# 0    Princy Odom        Street 1 New Lane       789456120    Client
# 1     Appy Alexa                Ac Street       568798821    Client
# 3  Clark Andrews   PO.BOX 156-Settle Road       123545342    Client
# 4     Riley Drew  PO.BOX 16-Thames Street       789821211  Internal
# 5    August Bork  PO.BOX 17-Thames Street       125921931  Internal
# 8    Erica Flint   Street 7 New Lane Road       789456128  Internal
#
#              Email
# 0  princy@text.com
# 1    appy@text.com
# 3   clark@text.com
# 4   riley@text.com
# 5     aug@text.com
# 8   erica@text.com

# %%
# f. Simpan dalam file dataset yang baru
path2 = '/content/drive/MyDrive/Machine Learning/dataset/dataset-uts-baru-2022.csv'
df.to_csv(path2)

# %%
df2 = pd.read_csv(path2)
df2
# Out:
#    Unnamed: 0           Nama                   Alamat  Nomor Handphone  \
# 0           0    Princy Odom        Street 1 New Lane        789456120
# 1           1     Appy Alexa                Ac Street        568798821
# 2           3  Clark Andrews   PO.BOX 156-Settle Road        123545342
# 3           4     Riley Drew  PO.BOX 16-Thames Street        789821211
# 4           5    August Bork  PO.BOX 17-Thames Street        125921931
# 5           8    Erica Flint   Street 7 New Lane Road        789456128
#
#      Projek            Email
# 0    Client  princy@text.com
# 1    Client    appy@text.com
# 2    Client   clark@text.com
# 3  Internal   riley@text.com
# 4  Internal     aug@text.com
# 5  Internal   erica@text.com
